# %% [markdown]
# # Simulace zpětné vazby STM a FM-AFM / STM and FM-AFM feedback simulation
#
# Interaktivní demonstrace pro výuku. Jazyk se přepíná nahoře v dashboardu.
# Interactive teaching demonstration. Switch the language at the top of the dashboard.
#
# Vytvořil Lukáš Hrdý za pomoci Claude Code. Chyby a připomínky posílejte na [hrdylukas1111@gmail.com](mailto:hrdylukas1111@gmail.com).
# Created by Lukáš Hrdý with the help of Claude Code. Please report bugs and feedback to [hrdylukas1111@gmail.com](mailto:hrdylukas1111@gmail.com).

# %%
# %matplotlib inline
import sys
from pathlib import Path

# Ve webové verzi (JupyterLite, Python v prohlížeči) se ipywidgets doinstaluje
# při startu; lokálně se tahle větev přeskočí.
if sys.platform == "emscripten":
    import piplite
    await piplite.install(["ipywidgets"])

# Notebook se spouští z kořene repa nebo z interactive/; tohle zajistí,
# že se moduly najdou v obou případech (i ve webové verzi).
KOREN = Path.cwd()
if not (KOREN / "stm_sim").is_dir():
    KOREN = Path.cwd().parent
sys.path.insert(0, str(KOREN))

from IPython.display import display

from interactive.dashboard_ui import build_dashboard

print("Připraveno / Ready:", KOREN)

# %%
display(build_dashboard())
